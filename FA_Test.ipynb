# %%
def get_widget(name, default=None):
    try:
        return dbutils.widgets.get(name)
    except:
        return default

file_path = get_widget("trigger.file_path")

print("Triggered file:", file_path)
